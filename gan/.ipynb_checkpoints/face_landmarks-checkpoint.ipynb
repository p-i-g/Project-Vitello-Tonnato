# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

WFLW_ROOT = "E:/pycharmgoesbrr/Project-Vitello-Tonnato/data/"

# %%
df = pd.read_csv(WFLW_ROOT + "WFLW_annotations/list_98pt_rect_attr_train_test/list_98pt_rect_attr_train.txt",
                 delimiter=" ", header=None)
df.head()
# Out:
#           0           1           2           3           4           5    \
# 0  309.307007  538.369019  317.857345  560.120847  322.271739  583.014395
# 1  579.002991  167.764008  579.682070  179.841323  580.396685  191.916578
# 2  249.128006  175.462997  249.330412  188.417601  249.393073  201.373615
# 3  812.989014  627.505005  813.713626  633.254430  814.450604  639.002281
# 4  507.287994  280.026001  507.360081  288.558285  507.747252  297.081106
#
#           6           7           8           9    ...  197  198  199  200  \
# 0  319.583872  606.149851  314.765287  629.015727  ...  308  696  870    0
# 1  581.180930  203.987499  582.094807  216.049139  ...   73  746  317    0
# 2  249.558448  214.328097  250.530592  227.243593  ...  104  420  330    0
# 3  815.212105  644.746929  816.041647  650.482018  ...  582  901  697    0
# 4  508.773408  305.548694  510.611932  313.877793  ...  212  632  379    0
#
# ...

# %%
raw_ds = tf.data.Dataset.from_tensor_slices(
    (df[range(196)].to_numpy().astype('float32'), df[range(196, 200)].to_numpy().astype('int32'), df[206].to_numpy()))

# %%
@tf.function
def gaussian(shape=(28, 28), peakValue=1.0, center=tf.constant((14.0, 14.0)),
             spread=1.0):  # center[i] between 0-shape[i]
    grid = tf.stack(
        tf.meshgrid(
            tf.range(shape[1], dtype=tf.float32),
            tf.range(shape[1], dtype=tf.float32)
        ),
        axis=-1
    )
    unstacked = tf.reshape(grid, [-1, 2])

    numerator = tf.square(center - unstacked)
    denominator = 2 * tf.square(spread)

    exponent = -tf.reduce_sum(numerator / denominator, axis=-1)

    unstacked_gaussian = peakValue * tf.exp(exponent)
    return tf.reshape(unstacked_gaussian, shape)


plt.imshow(gaussian(shape=[28, 28], peakValue=1.0, center=tf.constant((1, 14.5)), spread=1.0).numpy())

# %%
@tf.function
def offset(shape=(28, 28), center=tf.constant((0.5, 0.5))):  # center between 0-1
    grid = tf.stack(
        tf.meshgrid(
            tf.range(shape[1], dtype=tf.float32),
            tf.range(shape[1], dtype=tf.float32)
        ),
        axis=-1
    ) / shape[1]
    unstacked = tf.reshape(grid, [-1, 2])
    distances = unstacked - center
    x, y = tf.unstack(distances, axis=-1)
    return tf.reshape(x, shape), tf.reshape(y, shape)

# %%
plt.imshow(np.abs(offset(center=(0.8, 0.5))[0].numpy()))

# %%
def gen_data(landmarks, rect, filename):
    x_min, y_min, x_max, y_max = tf.unstack(rect)

    img = tf.io.read_file(WFLW_ROOT + "WFLW_images/" + filename)
    img = tf.image.decode_image(img)
    img = img[y_min: y_max, x_min:x_max, :]
    img = tf.image.resize_with_pad(img, 256, 256)

    landmarks = tf.reshape(landmarks, shape=(-1, 2))
    landmarks = landmarks - tf.cast(tf.stack([x_min, y_min]), tf.dtypes.float32)
    landmarks = landmarks / tf.cast(tf.stack([x_max - x_min, y_max - y_min]), tf.dtypes.float32)

    heatmaps = []
    x_offsets = []
    y_offsets = []

    for coords in tf.unstack(landmarks):
        heatmaps.append(gaussian(shape=(28, 28), peakValue=1.0, center=coords * 28, spread=1.0))
        x_offset, y_offset = offset(center = coords)
        x_offsets.append(x_offset)
        y_offsets.append(y_offset)

    heatmaps = tf.stack(heatmaps, axis=-1)
    x_offsets = tf.stack(x_offsets, axis=-1)
    y_offsets = tf.stack(y_offsets, axis=-1)

    return img, tf.concat([heatmaps, x_offsets, y_offsets], axis=-1)

# %%
for i in raw_ds.map(gen_data).take(1):
    plt.imshow(i[0].numpy().astype('int'))

# %%
import mobilenet
import keras.initializers.initializers_v2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers as KL
from tensorflow.keras import backend as K
from keras import models as KM
import tensorflow.keras.utils as KU
import ops

# %%
inputs = KL.Input(shape=(256, 256, 3))
C1, C2, C3, C4, C5 = mobilenet.mobilenetv3_large(inputs, include_preprocessing=False)
x = mobilenet.unet_block(C5, C4, 2.3, mobilenet.depth(256), 5, 1, 0.25, ops.HardSwish, 15)
x = mobilenet.unet_block(x, C3, 2.3, 294, 5, 1, 0.25, ops.HardSwish, 16)
model = KM.Model(inputs, x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  Conv (Conv2D)                  (None, 128, 128, 16  432         ['input_1[0][0]']
#                                 )
#
#  Conv/BatchNorm (BatchNormaliza  (None, 128, 128, 16  64         ['Conv[0][0]']
#  tion)                          )
#
#  Conv/activation (HardSwish)    (None, 128, 128, 16  0           ['Conv/BatchNorm[0][0]']
#                                 )
#
#  expanded_conv/depthwise (Depth  (None, 128, 128, 16  144        ['Conv/activation[0][0]']
#  wiseConv2D)                    )
#
#  expanded_conv/depthwise/BatchN  (None, 128, 128, 16  64         ['expanded_conv/depthwise[0][0]']
#  orm (BatchNormalization)       )
#
# ...
