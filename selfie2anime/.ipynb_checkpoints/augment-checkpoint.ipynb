# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from tensorflow.keras import layers as KL
from tensorflow.keras import utils as KU
from tensorflow.keras import models as KM
from tensorflow import keras
import logging
logging.getLogger('tensorflow').setLevel(logging.ERROR)  # suppress warnings

# %%
trainA = KU.image_dataset_from_directory("../data/selfie2anime/trainA", labels=None)
# Out:
# Found 3400 files belonging to 1 classes.

# %%
for f in trainA.take(1):
    plt.imshow(f[0].numpy().astype("int"))

# %%
def apply_augmentations(inputs):
    x = KL.RandomFlip('horizontal')(inputs)
    x = KL.RandomRotation((-0.15, 0.15))(x)
    x = KL.RandomZoom(-0.1, 0.1)(x)
    x = KL.RandomTranslation(0.1, 0.1)(x)
    x = keras.preprocessing.image.random_shear(x[0], 0.15)
    x = KL.Resizing(286, 286)(tf.expand_dims(x, axis=0))
    return KL.RandomCrop(256, 256)(x)

# %%
image = next(iter(trainA))[0]
plt.imshow(image.numpy().astype('int'))

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = apply_augmentations(tf.expand_dims(image, axis=0))
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0].numpy().astype('int'))
  plt.axis("off")
